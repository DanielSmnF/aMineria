# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielSmnF/aMineria/blob/main/ePearSpear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objetivo:
# Analizar un conjunto de datos, observar la relación entre variables, elegir el coeficiente de correlación adecuado y justifique su decisión con base en:
#
#     Tipo de relación
#     Presencia de outliers
#     Tipo de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datos_estudiantes_decision.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   horas_estudio  30 non-null     float64
#  1   calificacion   30 non-null     int64
#  2   nivel_estres   30 non-null     int64
#  3   horas_sueno    30 non-null     float64
#  4   uso_redes      30 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 1.3 KB

# %%
df.head()
# Out:
#    horas_estudio  calificacion  nivel_estres  horas_sueno  uso_redes
# 0           14.1            82             2          7.8        0.4
# 1            9.8            51             3          4.7        4.6
# 2            3.9            52             3          4.4        0.4
# 3           29.0            93             4          4.7        2.6
# 4           21.0            90             3          8.4        5.9

# %%
from matplotlib import figure
plt.figure(figsize=(6,4))
plt.scatter(data = df, x = "horas_estudio", y = "calificacion")
plt.title("Horas de Estudio vs Calificacion")
plt.xlabel("Horas de estudio")
plt.ylabel("Calificacion")
# Out:
# Text(0, 0.5, 'Calificacion')

# %%
plt.scatter(data=df, x = "horas_sueno", y="nivel_estres")
plt.title("Horas de Sueño vs Estres")
plt.xlabel("Horas de sueño")
plt.ylabel("Estres")
# Out:
# Text(0, 0.5, 'Estres')

# %%
plt.scatter(data=df, x = "uso_redes", y="calificacion")
plt.title("Uso de redes vs Calificacion")
plt.xlabel("Uso de redes")
plt.ylabel("Calificacion")
# Out:
# Text(0, 0.5, 'Calificacion')

# %% [markdown]
# **Pearson**

# %%
pearson_estudio_calf = df["horas_estudio"].corr(df["calificacion"], method="pearson")
pearson_sueno_estres = df["horas_sueno"].corr(df["nivel_estres"], method="pearson")
pearson_redes_calf = df["uso_redes"].corr(df["calificacion"], method="pearson")

# %%
print("Horas de Estudio vs Calificacion", pearson_estudio_calf)
print("Horas de Estudio vs Calificacion", pearson_sueno_estres)
print("Horas de Estudio vs Calificacion", pearson_redes_calf)
# Out:
# Horas de Estudio vs Calificacion 0.9292106764339317
# Horas de Estudio vs Calificacion -0.6778989431046725
# Horas de Estudio vs Calificacion -0.38281937366237423

# %% [markdown]
# **Spearman**

# %%
pearson_estudio_calf = df["horas_estudio"].corr(df["calificacion"], method="spearman")
pearson_sueno_estres = df["horas_sueno"].corr(df["nivel_estres"], method="spearman")
pearson_redes_calf = df["uso_redes"].corr(df["calificacion"], method="spearman")

# %%
print("Horas de Estudio vs Calificacion", pearson_estudio_calf)
print("Horas de Estudio vs Calificacion", pearson_sueno_estres)
print("Horas de Estudio vs Calificacion", pearson_redes_calf)
# Out:
# Horas de Estudio vs Calificacion 0.8877631929198361
# Horas de Estudio vs Calificacion -0.6624801373580795
# Horas de Estudio vs Calificacion -0.34886843048054694

# %% [markdown]
# **¿Coinciden Pearson y Spearman?**
#
# Sí, en signo y magnitud general, aunque Pearson tiende a ser ligeramente mayor cuando la relación es más lineal.

# %% [markdown]
# **¿Cambiarías tu decisión inicial?**
# No, los valores obtenidos confirman completamente las decisiones basadas en:
# *   Linealidad
# *   Tipo de variable
# *   Presencia de outliers
