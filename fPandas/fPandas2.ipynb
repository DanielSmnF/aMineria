# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielSmnF/aMineria/blob/main/fPandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIOS
#
#     Une orders_a y orders_b en un solo DataFrame orders con índice reiniciado.
#     Ordena orders por order_date ascendente y, en caso de empate, por qty descendente.
#     Establece order_date como índice en orders y ordena por índice (cronológico).

# %%
import pandas as pd

# %%
orders_a = pd.read_csv('part2_orders_a.csv')
orders_b = pd.read_csv('part2_orders_b.csv')

# %%
orders = pd.concat([orders_a, orders_b], ignore_index=True)

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders = orders.sort_values(
    by=['order_date', 'qty'],
    ascending=[True, False]
)

# %%
orders.set_index('order_date', inplace=True)

# %%
orders.sort_index(inplace=True)

# %%
orders.head()
# Out:
#             order_id  line_id customer_id product_id  qty channel
# order_date
# 2026-01-02      2001        1        C001        P10    2     web
# 2026-01-02      2002        2        C002        P20    1   store
# 2026-01-03      2003        3        C003        P20    3     web
# 2026-01-04      2004        4        C001        P30    1     app
# 2026-01-05      2005        5        C004        P10    5     web

# %% [markdown]
# Merge (enriquecer órdenes con clientes):
#
#     Haz un merge para añadir a orders las columnas del cliente (customer_name, city, segment) usando customer_id (left join). Valida que sea many_to_one.

# %%
customers = pd.read_csv('part2_customers.csv')

# %%
orders_enriched = orders.merge(
    customers[['customer_id', 'customer_name', 'city', 'segment']],
    on='customer_id',
    how='left',
    validate='many_to_one'
)

# %%
orders_enriched.head()
# Out:
#    order_id  line_id customer_id product_id  qty channel customer_name  city  \
# 0      2001        1        C001        P10    2     web           Ana  CDMX
# 1      2002        2        C002        P20    1   store          Luis   GDL
# 2      2003        3        C003        P20    3     web         Marta   MTY
# 3      2004        4        C001        P30    1     app           Ana  CDMX
# 4      2005        5        C004        P10    5     web         Sofia   QRO
#
#      segment
# 0   Consumer
# 1  Corporate
# 2   Consumer
# 3   Consumer
# 4  Small Biz

# %% [markdown]
# Merge (añadir producto y calcular total):
#
#     Haz un merge adicional con products para añadir product, category, unit_price y crea una columna line_total = qty * unit_price. Luego ordena por line_total descendente y muestra top 5.

# %%
products = pd.read_csv('part2_products.csv')

# %%
orders_full = orders_enriched.merge(
    products[['product_id', 'product', 'category', 'unit_price']],
    on='product_id',
    how='left',
    validate='many_to_one'
)

# %%
orders_full['line_total'] = orders_full['qty'] * orders_full['unit_price']

# %%
top_5 = orders_full.sort_values(
    by='line_total',
    ascending=False
).head(5)

# %%
top_5
# Out:
#    order_id  line_id customer_id product_id  qty channel customer_name  city  \
# 6      2007        7        C002        P30    2     web          Luis   GDL
# 5      2006        6        C005        P40    1   store         Diego   GDL
# 3      2004        4        C001        P30    1     app           Ana  CDMX
# 2      2003        3        C003        P20    3     web         Marta   MTY
# 9      2010       10        C008        P20    2   store         Ramon  CDMX
#
#      segment       product     category  unit_price  line_total
# 6  Corporate   Monitor 24"  Electronics       160.0       320.0
# 5   Consumer  Office Chair    Furniture       220.0       220.0
# 3   Consumer   Monitor 24"  Electronics       160.0       160.0
# 2   Consumer      Keyboard  Accessories        45.0       135.0
# 9  Small Biz      Keyboard  Accessories        45.0        90.0
